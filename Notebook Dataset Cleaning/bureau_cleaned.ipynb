# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %%
df = pd.read_csv('bureau_balance.csv')
pd.set_option('display.max_columns', None)

# %%
df.sample(10)
# Out:
#          SK_ID_BUREAU  MONTHS_BALANCE STATUS
# 1054          5717402           -83.0      0
# 232750        6360619           -24.0      C
# 738041        5229510           -31.0      C
# 890962        6588010            -4.0      X
# 113032        5263202            -4.0      0
# 60470         5002797           -32.0      C
# 645121        5843118           -27.0      0
# 547046        5834121           -35.0      0
# 1088762       6827318             0.0      C
# 35563         5235615           -88.0      0

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1144100 entries, 0 to 1144099
# Data columns (total 3 columns):
#  #   Column          Non-Null Count    Dtype
# ---  ------          --------------    -----
#  0   SK_ID_BUREAU    1144100 non-null  int64
#  1   MONTHS_BALANCE  1144099 non-null  float64
#  2   STATUS          1144099 non-null  object
# dtypes: float64(1), int64(1), object(1)
# memory usage: 26.2+ MB

# %%
pd.set_option('display.max_columns', None)

# Pilih kolom-kolom bertipe objek dan simpan dalam variabel 'categoric'
categoric = df.select_dtypes('object')

# Pilih kolom-kolom bertipe numerik dan simpan dalam variabel 'numeric'
numeric = df.select_dtypes('number')

# Tentukan jumlah baris dan kolom
rows = df.shape[0]
cols = df.shape[1]

# Cetak bentuk DataFrame
print(f'Jumlah Baris: {rows}\nJumlah Kolom: {cols}')

# Cetak ringkasan statistik data kategorikal
print('\nRingkasan Statistik Data Kategorikal:')
display(categoric.describe().T)

# Cetak ringkasan statistik data numerik
print('\nRingkasan Statistik Data Numerik:')
display(numeric.describe().T)
# Out:
# Jumlah Baris: 1144100
# Jumlah Kolom: 3
#
# Ringkasan Statistik Data Kategorikal:
#           count unique top    freq
# STATUS  1144099      8   C  560796
# Ringkasan Statistik Data Numerik:
#                     count          mean            std        min        25%  \
# SK_ID_BUREAU    1144100.0  5.970280e+06  511226.567887  5001726.0  5712547.0
# MONTHS_BALANCE  1144099.0 -2.968333e+01      23.373004      -96.0      -44.0
#
#                       50%         75%        max
# SK_ID_BUREAU    6007725.0  6539415.25  6834663.0
# MONTHS_BALANCE      -24.0      -10.00        0.0

# %%
df.isnull().sum()
# Out:
# SK_ID_BUREAU      0
# MONTHS_BALANCE    1
# STATUS            1
# dtype: int64

# %%
df.to_parquet('bureau_balance.parquet', index=False)

# %% [markdown]
# Karena data bureau_balance tidak memiliki nilai null, maka lanjut untuk cleaning data selanjutnya

# %%
df = pd.read_csv('bureau.csv')

# %%
df.sample(10)
# Out:
#          SK_ID_CURR  SK_ID_BUREAU CREDIT_ACTIVE CREDIT_CURRENCY  DAYS_CREDIT  \
# 711052       399967       5499512        Closed      currency 1        -2190
# 709602       362881       5497784        Closed      currency 1        -2743
# 73759        270221       5251145        Closed      currency 1        -2196
# 461338       451962       5043885        Closed      currency 1        -1763
# 435849       295522       5938137        Closed      currency 1         -351
# 1607083      445275       5343505        Closed      currency 1        -2627
# 609787       347298       6469102        Closed      currency 1        -1149
# 429309       233788       6833360        Closed      currency 1        -1034
# 1450958      140651       5786894        Active      currency 1         -537
# 126247       262238       5244361        Active      currency 1        -1290
#
#          CREDIT_DAY_OVERDUE  DAYS_CREDIT_ENDDATE  DAYS_ENDDATE_FACT  \
# 711052                    0              -1785.0            -1785.0
# 709602                    0              -2437.0            -2436.0
# 73759                     0              -1862.0            -1890.0
# 461338                    0              -1581.0            -1574.0
# 435849                    0                 14.0              -47.0
# 1607083                   0               -800.0             -818.0
# 609787                    0              -1059.0            -1059.0
# 429309                    0               -669.0             -698.0
# 1450958                   0                209.0                NaN
# 126247                    0                536.0                NaN
#
#          AMT_CREDIT_MAX_OVERDUE  CNT_CREDIT_PROLONG  AMT_CREDIT_SUM  \
# 711052                      NaN                   0        104647.5
# 709602                      NaN                   0         65565.0
# 73759                       0.0                   0         32157.0
# 461338                      NaN                   0         24745.5
# 435849                      0.0                   0         74830.5
# 1607083                     NaN                   0       1125000.0
# 609787                      NaN                   0         33520.5
# 429309                      NaN                   0        107712.0
# 1450958                     NaN                   0         32143.5
# 126247                      NaN                   0        741825.0
#
#          AMT_CREDIT_SUM_DEBT  AMT_CREDIT_SUM_LIMIT  AMT_CREDIT_SUM_OVERDUE  \
# 711052                   NaN                   NaN                     0.0
# 709602                   0.0                   NaN                     0.0
# 73759                    0.0                   0.0                     0.0
# 461338                   0.0                   NaN                     0.0
# 435849                   0.0                   0.0                     0.0
# 1607083                  0.0                   0.0                     0.0
# 609787                   0.0                   0.0                     0.0
# 429309                   0.0                   NaN                     0.0
# 1450958              11641.5                   NaN                     0.0
# 126247              290556.0                   0.0                     0.0
#
#              CREDIT_TYPE  DAYS_CREDIT_UPDATE  AMT_ANNUITY
# 711052   Consumer credit               -1785          NaN
# 709602   Consumer credit                -471          NaN
# 73759    Consumer credit               -1890          NaN
# 461338   Consumer credit               -1109          NaN
# 435849   Consumer credit                 -46          NaN
# 1607083  Consumer credit                -129          0.0
# 609787   Consumer credit                -999          0.0
# 429309   Consumer credit                -677          NaN
# 1450958  Consumer credit                  -7          NaN
# 126247   Consumer credit                  -9          NaN

# %%
pd.set_option('display.max_columns', None)

# Pilih kolom-kolom bertipe objek dan simpan dalam variabel 'categoric'
categoric = df.select_dtypes('object')

# Pilih kolom-kolom bertipe numerik dan simpan dalam variabel 'numeric'
numeric = df.select_dtypes('number')

# Tentukan jumlah baris dan kolom
rows = df.shape[0]
cols = df.shape[1]

# Cetak bentuk DataFrame
print(f'Jumlah Baris: {rows}\nJumlah Kolom: {cols}')

# Cetak ringkasan statistik data kategorikal
print('\nRingkasan Statistik Data Kategorikal:')
display(categoric.describe().T)

# Cetak ringkasan statistik data numerik
print('\nRingkasan Statistik Data Numerik:')
display(numeric.describe().T)
# Out:
# Jumlah Baris: 1716428
# Jumlah Kolom: 17
#
# Ringkasan Statistik Data Kategorikal:
#                    count unique              top     freq
# CREDIT_ACTIVE    1716428      4           Closed  1079273
# CREDIT_CURRENCY  1716428      4       currency 1  1715020
# CREDIT_TYPE      1716428     15  Consumer credit  1251615
# Ringkasan Statistik Data Numerik:
#                             count          mean           std          min  \
# SK_ID_CURR              1716428.0  2.782149e+05  1.029386e+05   100001.000
# SK_ID_BUREAU            1716428.0  5.924434e+06  5.322657e+05  5000000.000
# DAYS_CREDIT             1716428.0 -1.142108e+03  7.951649e+02    -2922.000
# CREDIT_DAY_OVERDUE      1716428.0  8.181666e-01  3.654443e+01        0.000
# DAYS_CREDIT_ENDDATE     1610875.0  5.105174e+02  4.994220e+03   -42060.000
# DAYS_ENDDATE_FACT       1082775.0 -1.017437e+03  7.140106e+02   -42023.000
# AMT_CREDIT_MAX_OVERDUE   591940.0  3.825418e+03  2.060316e+05        0.000
# CNT_CREDIT_PROLONG      1716428.0  6.410406e-03  9.622391e-02        0.000
# AMT_CREDIT_SUM          1716415.0  3.549946e+05  1.149811e+06        0.000
# AMT_CREDIT_SUM_DEBT     1458759.0  1.370851e+05  6.774011e+05 -4705600.320
# AMT_CREDIT_SUM_LIMIT    1124648.0  6.229515e+03  4.503203e+04  -586406.115
# AMT_CREDIT_SUM_OVERDUE  1716428.0  3.791276e+01  5.937650e+03        0.000
# DAYS_CREDIT_UPDATE      1716428.0 -5.937483e+02  7.207473e+02   -41947.000
# AMT_ANNUITY              489637.0  1.571276e+04  3.258269e+05        0.000
#
#                                25%        50%         75%           max
# SK_ID_CURR               188866.75   278055.0   367426.00  4.562550e+05
# SK_ID_BUREAU            5463953.75  5926303.5  6385681.25  6.843457e+06
# DAYS_CREDIT               -1666.00     -987.0     -474.00  0.000000e+00
# CREDIT_DAY_OVERDUE            0.00        0.0        0.00  2.792000e+03
# DAYS_CREDIT_ENDDATE       -1138.00     -330.0      474.00  3.119900e+04
# DAYS_ENDDATE_FACT         -1489.00     -897.0     -425.00  0.000000e+00
# AMT_CREDIT_MAX_OVERDUE        0.00        0.0        0.00  1.159872e+08
# CNT_CREDIT_PROLONG            0.00        0.0        0.00  9.000000e+00
# AMT_CREDIT_SUM            51300.00   125518.5   315000.00  5.850000e+08
# AMT_CREDIT_SUM_DEBT           0.00        0.0    40153.50  1.701000e+08
# AMT_CREDIT_SUM_LIMIT          0.00        0.0        0.00  4.705600e+06
# AMT_CREDIT_SUM_OVERDUE        0.00        0.0        0.00  3.756681e+06
# DAYS_CREDIT_UPDATE         -908.00     -395.0      -33.00  3.720000e+02
# AMT_ANNUITY                   0.00        0.0    13500.00  1.184534e+08

# %%
dfe = df.copy()
# Memeriksa baris duplikat
duplicate_rows = dfe.duplicated()

# Menampilkan jumlah baris duplikat
print(f"Jumlah baris duplikat: {duplicate_rows.sum()}")

# Fungsi untuk menghitung dan menampilkan kolom dengan nilai missing
def check_nan(dfe):
    # Hitung nilai null
    null_values = dfe.isnull().sum()

    # Buat DataFrame untuk total nilai null dan persentase
    nvc = pd.DataFrame(null_values[null_values > 0].sort_values(), columns=['Total Null Values'])  # Hanya ambil kolom dengan nilai null
    nvc['Percentage'] = (nvc['Total Null Values'] / dfe.shape[0]) * 100
    nvc["Data Type"] = [dfe[col].dtype for col in nvc.index]  # Ambil tipe data dari kolom yang ada

    # Urutkan berdasarkan total nilai null dan persentase
    nvc.sort_values(by=["Total Null Values", "Percentage"], ascending=False, inplace=True)

    # Tampilkan hasil dengan gaya
    return nvc.style.background_gradient(cmap='Blues')

# Panggil fungsi dan simpan hasilnya
styled_result = check_nan(dfe)

# Untuk menampilkan hasil di Jupyter Notebook, gunakan:
styled_result
# Out:
# Jumlah baris duplikat: 0
# <style type="text/css">
# #T_407d2_row0_col0, #T_407d2_row0_col1 {
#   background-color: #08306b;
#   color: #f1f1f1;
# }
# #T_407d2_row1_col0, #T_407d2_row1_col1 {
#   background-color: #08468b;
#   color: #f1f1f1;
# }
# #T_407d2_row2_col0, #T_407d2_row2_col1 {
#   background-color: #65aad4;
#   color: #f1f1f1;
# }
# #T_407d2_row3_col0, #T_407d2_row3_col1 {
#   background-color: #72b2d8;
#   color: #f1f1f1;
# }
# #T_407d2_row4_col0, #T_407d2_row4_col1 {
#   background-color: #cee0f2;
#   color: #000000;
# }
# #T_407d2_row5_col0, #T_407d2_row5_col1 {
#   background-color: #e6f0f9;
#   color: #000000;
# }
# #T_407d2_row6_col0, #T_407d2_row6_col1 {
#   background-color: #f7fbff;
#   color: #000000;
# }
# </style>
# <table id="T_407d2" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_407d2_level0_col0" class="col_heading level0 col0" >Total Null Values</th>
#       <th id="T_407d2_level0_col1" class="col_heading level0 col1" >Percentage</th>
#       <th id="T_407d2_level0_col2" class="col_heading level0 col2" >Data Type</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_407d2_level0_row0" class="row_heading level0 row0" >AMT_ANNUITY</th>
#       <td id="T_407d2_row0_col0" class="data row0 col0" >1226791</td>
#       <td id="T_407d2_row0_col1" class="data row0 col1" >71.473490</td>
#       <td id="T_407d2_row0_col2" class="data row0 col2" >float64</td>
#     </tr>
#     <tr>
#       <th id="T_407d2_level0_row1" class="row_heading level0 row1" >AMT_CREDIT_MAX_OVERDUE</th>
#       <td id="T_407d2_row1_col0" class="data row1 col0" >1124488</td>
#       <td id="T_407d2_row1_col1" class="data row1 col1" >65.513264</td>
#       <td id="T_407d2_row1_col2" class="data row1 col2" >float64</td>
#     </tr>
#     <tr>
#       <th id="T_407d2_level0_row2" class="row_heading level0 row2" >DAYS_ENDDATE_FACT</th>
#       <td id="T_407d2_row2_col0" class="data row2 col0" >633653</td>
#       <td id="T_407d2_row2_col1" class="data row2 col1" >36.916958</td>
#       <td id="T_407d2_row2_col2" class="data row2 col2" >float64</td>
#     </tr>
#     <tr>
#       <th id="T_407d2_level0_row3" class="row_heading level0 row3" >AMT_CREDIT_SUM_LIMIT</th>
#       <td id="T_407d2_row3_col0" class="data row3 col0" >591780</td>
#       <td id="T_407d2_row3_col1" class="data row3 col1" >34.477415</td>
#       <td id="T_407d2_row3_col2" class="data row3 col2" >float64</td>
#     </tr>
#     <tr>
#       <th id="T_407d2_level0_row4" class="row_heading level0 row4" >AMT_CREDIT_SUM_DEBT</th>
#       <td id="T_407d2_row4_col0" class="data row4 col0" >257669</td>
#       <td id="T_407d2_row4_col1" class="data row4 col1" >15.011932</td>
#       <td id="T_407d2_row4_col2" class="data row4 col2" >float64</td>
#     </tr>
#     <tr>
#       <th id="T_407d2_level0_row5" class="row_heading level0 row5" >DAYS_CREDIT_ENDDATE</th>
#       <td id="T_407d2_row5_col0" class="data row5 col0" >105553</td>
#       <td id="T_407d2_row5_col1" class="data row5 col1" >6.149573</td>
#       <td id="T_407d2_row5_col2" class="data row5 col2" >float64</td>
#     </tr>
#     <tr>
#       <th id="T_407d2_level0_row6" class="row_heading level0 row6" >AMT_CREDIT_SUM</th>
#       <td id="T_407d2_row6_col0" class="data row6 col0" >13</td>
#       <td id="T_407d2_row6_col1" class="data row6 col1" >0.000757</td>
#       <td id="T_407d2_row6_col2" class="data row6 col2" >float64</td>
#     </tr>
#   </tbody>
# </table>

# %%
cols_drop = dfe.columns[dfe.isnull().mean() > 0.5]
dfe.drop(cols_drop, axis=1, inplace=True)

#karena tipe data yg null adalah float semua, maka imputasi berdasarkan median saja
# 1. imputasi data missing 10 - 50%
for col in dfe.columns:
  if 0.1 < dfe[col].isnull().mean() <= 0.5:
    dfe[col].fillna(dfe[col].median(), inplace=True)

# 2. imputasi data missing < 10%
for col in dfe.columns:
  if dfe[col].isnull().mean() < 0.1:
    dfe[col].fillna(dfe[col].mode()[0], inplace=True)

# cek hasil akhir
styled_result = check_nan(dfe)
styled_result
# Out:
# <style type="text/css">
# </style>
# <table id="T_d5790" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_d5790_level0_col0" class="col_heading level0 col0" >Total Null Values</th>
#       <th id="T_d5790_level0_col1" class="col_heading level0 col1" >Percentage</th>
#       <th id="T_d5790_level0_col2" class="col_heading level0 col2" >Data Type</th>
#     </tr>
#   </thead>
#   <tbody>
#   </tbody>
# </table>

# %%
#simpan
dfe.to_parquet('bureau_cleaned.parquet', index=False)
